# %% [markdown]
# This code returns the csv version of the files, with nested versions of the arrays from Configuration Node, Description Data, Problem Type, and Reference Data

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize 

with open("nvdcve-1.1-2005.json") as f:
    d = json.load(f)

# %%
nvd = json_normalize(d["CVE_Items"])
nvd
# Out:
#      configurations.CVE_data_version  \
# 0                                4.0
# 1                                4.0
# 2                                4.0
# 3                                4.0
# 4                                4.0
# 5                                4.0
# 6                                4.0
# 7                                4.0
# 8                                4.0
# 9                                4.0
# 10                               4.0
# 11                               4.0
# 12                               4.0
# 13                               4.0
# 14                               4.0
# 15                               4.0
# 16                               4.0
# 17                               4.0
# 18                               4.0
# 19                               4.0
# 20                               4.0
# 21                               4.0
# 22                               4.0
# 23                               4.0
# ...

# %%
#nvd.iloc[0]

# %%
#export_csv = nvd.to_csv (r'\nvdcve-1.1-2005.csv', index = None, header=True)
