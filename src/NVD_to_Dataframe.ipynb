# %% [markdown]
# ### Parsed NVD to Dataframe

# %%
import pandas as pd

file2019 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2019-cvehash.csv'
file2018 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2018-cvehash.csv'
file2017 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2017-cvehash.csv'
file2016 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2016-cvehash.csv'
file2015 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2015-cvehash.csv'
file2014 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2014-cvehash.csv'
file2013 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2013-cvehash.csv'
file2012 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2012-cvehash.csv'
file2011 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2011-cvehash.csv'
file2010 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2010-cvehash.csv'
file2009 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2009-cvehash.csv'
file2008 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2008-cvehash.csv'
file2007 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2007-cvehash.csv'
file2006 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2006-cvehash.csv'
file2005 = 'C:/Users/Faugh/Desktop/Open_Source_Vul_Metrics/data/nvd-hashs/2005-cvehash.csv'


df2019 = pd.read_csv(file2019)
df2018 = pd.read_csv(file2018)
df2017 = pd.read_csv(file2017)
df2016 = pd.read_csv(file2016)
df2015 = pd.read_csv(file2015)
df2014 = pd.read_csv(file2014)
df2013 = pd.read_csv(file2013)
df2012 = pd.read_csv(file2012)
df2011 = pd.read_csv(file2011)
df2010 = pd.read_csv(file2010)
df2009 = pd.read_csv(file2009)
df2008 = pd.read_csv(file2008)
df2007 = pd.read_csv(file2007)
df2006 = pd.read_csv(file2006)
df2005 = pd.read_csv(file2005)

df_full_concatination = pd.concat([df2019, df2018, df2017, df2016, df2015, df2014, df2013, df2012, df2011, df2010, df2009, df2008, df2007, df2006, df2005], ignore_index=True)
df_full_concatination
# Out:
#      cveid  year                                      hash  \
# 0      654  2019  fd37bd8fb2b9c306079db505e0e3fe79a096c31c
# 1      659  2019  33e2692a37b5b6340cf5bec1a84e541460983c03
# 2      660  2019  b97a4b658814b2de8b9f2a3bce491c002d34de31
# 3      661  2019  33e2692a37b5b6340cf5bec1a84e541460983c03
# 4      826  2019  81a4b8620188e89f7e4fc985f3c89b58d4bcc86b
# 5      826  2019  aaece6921d7368577511f06c94c99dd4e9653563
# 6      878  2019  09f0ab871bf633973cfd9fc4fe59d4a912397cf8
# 7      879  2019  114cd3d0aac8bd1aeaf4b33840feb0163d342d5b
# 8      930  2019  a0e0d7de20f5d1712f1793f925496def4383c610
# 9      932  2019  c145d4604df67e6fc625992412eef0bf9a85e26b
# 10     932  2019  f6660e6d8f0d1d931359d591dbdec580fef36d36
# 11     939  2019  f30f9339c9a0b9bbcc6f5ad38804af39db1f479e
# 12     951  2019  b9150b7194f8cfb1178ca3674a0b3c86b7cd92f5
# 13     951  2019  f1c2f906410bf35bb6bd45efff57d2e8da3b3825
# 14     953  2019  be749d7efa7c9021da746e685bd6dec79f9dd99b
# ...
